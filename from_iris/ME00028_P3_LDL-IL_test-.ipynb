# %%
#import necessary python packages
import pandas as pd
import numpy as np
import sys
import seaborn as sns
sns.set_context('paper')

#provide the path to local folder containing python functions for pbmc analysis
sys.path.insert(1, '/home/ilmoncyte/Documents/analyses/cell_data_analyses/pbmc_analysis_tools/')

#import functions for pbmc analysis
from DataPrepIL import DataPrep
from NormaliseData import NormaliseData
from Plate import Plate
from DataCleanup import DataCleanup
from WellCalc import WellCalc
from DrawHeatmap import DrawHeatmap
from FoldCalc import FoldCalc

#provide paths to used folders
where = '/home/ilmoncyte/Documents/analyses/testing_data/'
layouts_folder = where+ 'layouts/' # where your csv layout file is located
results_folder = where+ 'cellp_results/' #where is your cellprofiler output folder located
output_folder = where+ 'out_results/'

# %%
pd.set_option('display.max_columns', None)
#provide the name of the cellprofiler output file
filename = 'ME00028_P3_Cells.csv' 


file_loc = results_folder + filename
print('Data location: ',file_loc)

#read the cellprofiler output file and extract experiment and run name from the filename
sr_all = pd.read_csv(file_loc)
print(sr_all)
exp_name = filename[:-10]
print('Experiment name: ',exp_name)
run_name = filename[0:6]
print('Run name: ', run_name)


experimentlayout = layouts_folder+exp_name+'_layout.csv'
print('Plate layout: ',experimentlayout)


#initialise the class for transforming the dataframe to readable format
my_frame = DataPrep(file_loc, exp_name)
print(my_frame)
#set the stain name for channel C

#set the stain name for channel D
my_frame.set_stain_d('DiI')
print('Stain C = ', my_frame.stain_c)

#set the cut_off
my_frame.set_cutoff(100)

dat = my_frame.org_calc(experimentlayout, 384)
print(dat.head(2))
#remove outliers on a single-cell level
clean_data = DataCleanup(5)

cdat = clean_data.cl_fraction(dat,'cell_area')
print(cdat.head(2))
print('removed ', dat.shape[0] - cdat.shape[0], ' cells out of ', dat.shape[0], ' based on cell area')

#cdat1 = clean_data.cl_well_fract(cdat, 'Size_DiIOrg')
#print('removed ', cdat.shape[0] - cdat1.shape[0], ' cells out of ', cdat.shape[0], ' based on DiIOrg size')


#save single-cell data with outliers removed 
cdat.to_csv(output_folder+'single_cell_cleaned/'+exp_name+'_cell_clean.csv')
# Out:
# Data location:  /home/ilmoncyte/Documents/analyses/testing_data/cellp_results/ME00028_P3_Cells.csv
#         ImageNumber  ObjectNumber  Metadata_FileLocation  \
# 0                 1             1                    NaN
# 1                 1             2                    NaN
# 2                 1             3                    NaN
# 3                 1             4                    NaN
# 4                 1             5                    NaN
# ...             ...           ...                    ...
# 176892          576           349                    NaN
# 176893          576           350                    NaN
# 176894          576           351                    NaN
# 176895          576           352                    NaN
# 176896          576           353                    NaN
#
#             Metadata_Filename    Metadata_Filename.1  Metadata_Frame  \
# 0       r03c02f1-ch2_MIP.tiff  r03c02f1-ch2_MIP.tiff               0
# 1       r03c02f1-ch2_MIP.tiff  r03c02f1-ch2_MIP.tiff               0
# 2       r03c02f1-ch2_MIP.tiff  r03c02f1-ch2_MIP.tiff               0
# 3       r03c02f1-ch2_MIP.tiff  r03c02f1-ch2_MIP.tiff               0
# 4       r03c02f1-ch2_MIP.tiff  r03c02f1-ch2_MIP.tiff               0
# ...                       ...                    ...             ...
# 176892  r14c07f9-ch2_MIP.tiff  r14c07f9-ch2_MIP.tiff               0
# 176893  r14c07f9-ch2_MIP.tiff  r14c07f9-ch2_MIP.tiff               0
# 176894  r14c07f9-ch2_MIP.tiff  r14c07f9-ch2_MIP.tiff               0
# 176895  r14c07f9-ch2_MIP.tiff  r14c07f9-ch2_MIP.tiff               0
# 176896  r14c07f9-ch2_MIP.tiff  r14c07f9-ch2_MIP.tiff               0
#
#         Metadata_Series  AreaShape_Area  Children_SpotsD_Count  \
# 0                     0            2068                      0
# 1                     0            2018                      0
# 2                     0            1939                      0
# 3                     0            1227                      0
# 4                     0            2190                      0
# ...                 ...             ...                    ...
# 176892                0            1713                      0
# 176893                0            1198                      1
# 176894                0             811                      0
# 176895                0            1445                      0
# 176896                0            3688                      2
#
#         Intensity_IntegratedIntensity_D  Intensity_MeanIntensity_D  \
# 0                              3.657374                   0.001769
# 1                              3.509880                   0.001739
# 2                              3.533089                   0.001822
# 3                              2.252384                   0.001836
# 4                              3.984649                   0.001819
# ...                                 ...                        ...
# 176892                         5.689403                   0.003321
# 176893                        28.750057                   0.023998
# 176894                         5.995697                   0.007393
# 176895                        13.009690                   0.009003
# 176896                       109.123247                   0.029589
#
#         Intensity_MedianIntensity_D  Location_CenterMassIntensity_X_D  \
# 0                          0.001770                        417.583555
# 1                          0.001740                        181.018603
# 2                          0.001816                        649.947668
# 3                          0.001831                       1559.502229
# 4                          0.001816                        524.350253
# ...                             ...                               ...
# 176892                     0.002777                        803.880892
# 176893                     0.010636                       1095.723877
# 176894                     0.003388                        509.962711
# 176895                     0.004829                       1920.040939
# 176896                     0.011887                       2062.057046
#
#         Location_CenterMassIntensity_Y_D  Location_CenterMassIntensity_Z_D  \
# 0                              30.165120                               0.0
# 1                              37.387697                               0.0
# 2                              43.396707                               0.0
# 3                              47.817770                               0.0
# 4                              55.890447                               0.0
# ...                                  ...                               ...
# 176892                       2140.176304                               0.0
# 176893                       2148.693854                               0.0
# 176894                       2146.361529                               0.0
# 176895                       2150.471675                               0.0
# 176896                       2136.120447                               0.0
#
#         Location_Center_X  Location_Center_Y  Location_Center_Z  \
# 0              417.543520          30.099613                  0
# 1              180.999009          37.315164                  0
# 2              649.972666          43.379061                  0
# 3             1559.555012          47.835371                  0
# 4              524.376712          55.789041                  0
# ...                   ...                ...                ...
# 176892         801.932283        2139.756567                  0
# 176893        1088.335559        2145.117696                  0
# 176894         504.963009        2147.806412                  0
# 176895        1914.662284        2150.021453                  0
# 176896        2067.591377        2137.071041                  0
#
#         Location_MaxIntensity_X_D  Location_MaxIntensity_Y_D  \
# 0                           394.0                       40.0
# 1                           178.0                       50.0
# 2                           644.0                       23.0
# 3                          1553.0                       39.0
# 4                           525.0                       74.0
# ...                           ...                        ...
# 176892                      810.0                     2151.0
# 176893                     1109.0                     2152.0
# 176894                      514.0                     2146.0
# 176895                     1923.0                     2149.0
# 176896                     2051.0                     2133.0
#
#         Location_MaxIntensity_Z_D  Mean_SpotsD_AreaShape_Area  \
# 0                             0.0                         NaN
# 1                             0.0                         NaN
# 2                             0.0                         NaN
# 3                             0.0                         NaN
# 4                             0.0                         NaN
# ...                           ...                         ...
# 176892                        0.0                         NaN
# 176893                        0.0                        68.0
# 176894                        0.0                         NaN
# 176895                        0.0                         NaN
# 176896                        0.0                        55.5
#
#         Mean_SpotsD_Intensity_IntegratedIntensity_D  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 176892                                          NaN
# 176893                                    13.051698
# 176894                                          NaN
# 176895                                          NaN
# 176896                                    13.786252
#
#         Mean_SpotsD_Intensity_MeanIntensity_D  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 176892                                    NaN
# 176893                               0.191937
# 176894                                    NaN
# 176895                                    NaN
# 176896                               0.224437
#
#         Mean_SpotsD_Intensity_MedianIntensity_D  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 176892                                      NaN
# 176893                                 0.188098
# 176894                                      NaN
# 176895                                      NaN
# 176896                                 0.207923
#
#         Mean_SpotsD_Location_CenterMassIntensity_X_D  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 176892                                           NaN
# 176893                                   1111.697914
# 176894                                           NaN
# 176895                                           NaN
# 176896                                   2061.543138
#
#         Mean_SpotsD_Location_CenterMassIntensity_Y_D  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 176892                                           NaN
# 176893                                   2151.144595
# 176894                                           NaN
# 176895                                           NaN
# 176896                                   2131.051713
#
#         Mean_SpotsD_Location_CenterMassIntensity_Z_D  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 176892                                           NaN
# 176893                                           0.0
# 176894                                           NaN
# 176895                                           NaN
# 176896                                           0.0
#
#         Mean_SpotsD_Location_Center_X  Mean_SpotsD_Location_Center_Y  \
# 0                                 NaN                            NaN
# 1                                 NaN                            NaN
# 2                                 NaN                            NaN
# 3                                 NaN                            NaN
# 4                                 NaN                            NaN
# ...                               ...                            ...
# 176892                            NaN                            NaN
# 176893                    1111.779412                    2151.073529
# 176894                            NaN                            NaN
# 176895                            NaN                            NaN
# 176896                    2061.790424                    2131.228414
#
#         Mean_SpotsD_Location_Center_Z  Mean_SpotsD_Location_MaxIntensity_X_D  \
# 0                                 NaN                                    NaN
# 1                                 NaN                                    NaN
# 2                                 NaN                                    NaN
# 3                                 NaN                                    NaN
# 4                                 NaN                                    NaN
# ...                               ...                                    ...
# 176892                            NaN                                    NaN
# 176893                            0.0                                 1109.0
# 176894                            NaN                                    NaN
# 176895                            NaN                                    NaN
# 176896                            0.0                                 2061.0
#
#         Mean_SpotsD_Location_MaxIntensity_Y_D  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 176892                                    NaN
# 176893                                 2152.0
# 176894                                    NaN
# 176895                                    NaN
# 176896                                 2131.0
#
#         Mean_SpotsD_Location_MaxIntensity_Z_D  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 176892                                    NaN
# 176893                                    0.0
# 176894                                    NaN
# 176895                                    NaN
# 176896                                    0.0
#
#         Mean_SpotsD_Number_Object_Number  Number_Object_Number  Parent_Nuclei
# 0                                    NaN                     1              1
# 1                                    NaN                     2              2
# 2                                    NaN                     3              3
# 3                                    NaN                     4              4
# 4                                    NaN                     5              5
# ...                                  ...                   ...            ...
# 176892                               NaN                   349            349
# 176893                             216.0                   350            350
# 176894                               NaN                   351            351
# 176895                               NaN                   352            352
# 176896                             214.5                   353            353
#
# [176897 rows x 37 columns]
# Experiment name:  ME00028_P3
# Run name:  ME0002
# Plate layout:  /home/ilmoncyte/Documents/analyses/testing_data/layouts/ME00028_P3_layout.csv
# <DataPrepIL.DataPrep object at 0x7867c1347d90>
# Stain C =  CD36
#        well Names
# 0       NaN     A
# 1    r01c01   NaN
# 2    r01c02   NaN
# 3    r01c03   NaN
# 4    r01c04   NaN
# ..      ...   ...
# 395  r16c20   NaN
# 396  r16c21   NaN
# 397  r16c22   NaN
# 398  r16c23   NaN
# 399  r16c24   NaN
#
# [400 rows x 2 columns]
#        Metadata_Filename  cell_area  DiIOrg    IntDiI   MeanDiI   MedDiI  \
# 0  r03c02f1-ch2_MIP.tiff       2068       0  3.657374  0.001769  0.00177
# 1  r03c02f1-ch2_MIP.tiff       2018       0  3.509880  0.001739  0.00174
#
#    Size_DiIOrg  MeanIntDiI_DiIOrg  MeanMeanDiI_DiIOrg  MeanMedDiI_DiIOrg  \
# 0          NaN                NaN                 NaN                NaN
# 1          NaN                NaN                 NaN                NaN
#
#    experiment  um_cell_area  Monocyte shortnames    well Sample treatment  \
# 0  ME00028_P3     46.216607  negative     r03c02  r03c02     BG        CM
# 1  ME00028_P3     45.099184  negative     r03c02  r03c02     BG        CM
#
#   DiIOrg_pos  um_DiIOrg_size  total_DiIOrg_size  um_total_DiIOrg_size  \
# 0   negative             NaN                NaN                   NaN
# 1   negative             NaN                NaN                   NaN
#
#    total_DiI_meanint_of_DiIOrg  total_DiI_meanmean_of_DiIOrg  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
#
#    total_DiI_meanmed_of_DiIOrg
# 0                          NaN
# 1                          NaN
#        Metadata_Filename  cell_area  DiIOrg    IntDiI   MeanDiI   MedDiI  \
# 0  r03c02f1-ch2_MIP.tiff     2068.0     0.0  3.657374  0.001769  0.00177
# 1  r03c02f1-ch2_MIP.tiff     2018.0     0.0  3.509880  0.001739  0.00174
#
#    Size_DiIOrg  MeanIntDiI_DiIOrg  MeanMeanDiI_DiIOrg  MeanMedDiI_DiIOrg  \
# 0          NaN                NaN                 NaN                NaN
# 1          NaN                NaN                 NaN                NaN
#
#    experiment  um_cell_area  Monocyte shortnames    well Sample treatment  \
# 0  ME00028_P3     46.216607  negative     r03c02  r03c02     BG        CM
# 1  ME00028_P3     45.099184  negative     r03c02  r03c02     BG        CM
#
#   DiIOrg_pos  um_DiIOrg_size  total_DiIOrg_size  um_total_DiIOrg_size  \
# 0   negative             NaN                NaN                   NaN
# 1   negative             NaN                NaN                   NaN
#
#    total_DiI_meanint_of_DiIOrg  total_DiI_meanmean_of_DiIOrg  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
#
#    total_DiI_meanmed_of_DiIOrg
# 0                          NaN
# 1                          NaN
# removed  13  cells out of  176897  based on cell area
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 44
#      41 print('removed ', dat.shape[0] - cdat.shape[0], ' cells out of ', dat.shape[0], ' based on cell area')
#      43 #cdat1 = clean_data.cl_well_fract(cdat, 'Size_DiIOrg')
# ---> 44 print('removed ', cdat.shape[0] - cdat1.shape[0], ' cells out of ', cdat.shape[0], ' based on DiIOrg size')
#      47 #save single-cell data with outliers removed
#      48 cdat.to_csv(output_folder+'single_cell_cleaned/'+exp_name+'_cell_clean.csv')
#
# NameError: name 'cdat1' is not defined
