# %%
#import necessary python packages
import pandas as pd
import numpy as np
import sys
import seaborn as sns
sns.set_context('paper')

#provide the path to local folder containing python functions for pbmc analysis
sys.path.insert(1, '/home/ilmoncyte/Documents/analyses/cell_data_analyses/pbmc_analysis_tools/')

#import functions for pbmc analysis
from DataPrepIL import DataPrep
from NormaliseData import NormaliseData
from Plate import Plate
from DataCleanup import DataCleanup
from WellCalc import WellCalc
from DrawHeatmap import DrawHeatmap
from FoldCalc import FoldCalc

#provide paths to used folders
where = '/home/ilmoncyte/Documents/analyses/testing_data/'
layouts_folder = where+ 'layouts/' # where your csv layout file is located
results_folder = where+ 'cellp_results/' #where is your cellprofiler output folder located
output_folder = where+ 'out_results/'

# %%
pd.set_option('display.max_columns', None)
#provide the name of the cellprofiler output file
filename = 'ME00028_P4_Cells.csv' 


file_loc = results_folder + filename
print('Data location: ',file_loc)

#read the cellprofiler output file and extract experiment and run name from the filename
sr_all = pd.read_csv(file_loc)
print(sr_all)
exp_name = filename[:-10]
print('Experiment name: ',exp_name)
run_name = filename[0:6]
print('Run name: ', run_name)


experimentlayout = layouts_folder+exp_name+'_layout.csv'
print('Plate layout: ',experimentlayout)


#initialise the class for transforming the dataframe to readable format
my_frame = DataPrep(file_loc, exp_name)
print(my_frame)
#set the stain name for channel C

#set the stain name for channel D
my_frame.set_stain_d('DiI')
print('Stain C = ', my_frame.stain_c)

#set the cut_off
my_frame.set_cutoff(100)

dat = my_frame.org_calc(experimentlayout, 384)
print(dat.head(2))
#remove outliers on a single-cell level
clean_data = DataCleanup(5)

cdat = clean_data.cl_fraction(dat,'cell_area')
print(cdat.head(2))
print('removed ', dat.shape[0] - cdat.shape[0], ' cells out of ', dat.shape[0], ' based on cell area')

#cdat1 = clean_data.cl_well_fract(cdat, 'Size_DiIOrg')
#print('removed ', cdat.shape[0] - cdat1.shape[0], ' cells out of ', cdat.shape[0], ' based on DiIOrg size')


#save single-cell data with outliers removed 
cdat.to_csv(output_folder+'single_cell_cleaned/'+exp_name+'_cell_clean.csv')
# Out:
# Data location:  /home/ilmoncyte/Documents/analyses/testing_data/cellp_results/ME00028_P4_Cells.csv
#        ImageNumber  ObjectNumber  Metadata_FileLocation  \
# 0                1             1                    NaN
# 1                1             2                    NaN
# 2                1             3                    NaN
# 3                1             4                    NaN
# 4                1             5                    NaN
# ...            ...           ...                    ...
# 91230          288           319                    NaN
# 91231          288           320                    NaN
# 91232          288           321                    NaN
# 91233          288           322                    NaN
# 91234          288           323                    NaN
#
#            Metadata_Filename    Metadata_Filename.1  Metadata_Frame  \
# 0      r03c03f1-ch2_MIP.tiff  r03c03f1-ch2_MIP.tiff               0
# 1      r03c03f1-ch2_MIP.tiff  r03c03f1-ch2_MIP.tiff               0
# 2      r03c03f1-ch2_MIP.tiff  r03c03f1-ch2_MIP.tiff               0
# 3      r03c03f1-ch2_MIP.tiff  r03c03f1-ch2_MIP.tiff               0
# 4      r03c03f1-ch2_MIP.tiff  r03c03f1-ch2_MIP.tiff               0
# ...                      ...                    ...             ...
# 91230  r10c06f9-ch2_MIP.tiff  r10c06f9-ch2_MIP.tiff               0
# 91231  r10c06f9-ch2_MIP.tiff  r10c06f9-ch2_MIP.tiff               0
# 91232  r10c06f9-ch2_MIP.tiff  r10c06f9-ch2_MIP.tiff               0
# 91233  r10c06f9-ch2_MIP.tiff  r10c06f9-ch2_MIP.tiff               0
# 91234  r10c06f9-ch2_MIP.tiff  r10c06f9-ch2_MIP.tiff               0
#
#        Metadata_Series  AreaShape_Area  Children_SpotsD_Count  \
# 0                    0            1996                      0
# 1                    0            2481                      0
# 2                    0            1782                      0
# 3                    0            5159                      0
# 4                    0            4839                      0
# ...                ...             ...                    ...
# 91230                0            1883                      0
# 91231                0            1971                      1
# 91232                0            1959                      0
# 91233                0            2164                      0
# 91234                0             714                      0
#
#        Intensity_IntegratedIntensity_D  Intensity_MeanIntensity_D  \
# 0                             5.978805                   0.002995
# 1                             7.153643                   0.002883
# 2                             4.022263                   0.002257
# 3                            10.781903                   0.002090
# 4                            10.644358                   0.002200
# ...                                ...                        ...
# 91230                         7.472496                   0.003968
# 91231                       170.734600                   0.086623
# 91232                         6.627146                   0.003383
# 91233                        12.606638                   0.005826
# 91234                         7.747067                   0.010850
#
#        Intensity_MedianIntensity_D  Location_CenterMassIntensity_X_D  \
# 0                         0.002960                       1196.709574
# 1                         0.002518                       1806.115299
# 2                         0.002090                        501.878512
# 3                         0.002045                       1241.371196
# 4                         0.002060                        968.797952
# ...                            ...                               ...
# 91230                     0.003662                       1982.197057
# 91231                     0.003899                        322.067148
# 91232                     0.003052                       1449.910152
# 91233                     0.003983                        489.171775
# 91234                     0.007065                        872.435557
#
#        Location_CenterMassIntensity_Y_D  Location_CenterMassIntensity_Z_D  \
# 0                             16.722391                               0.0
# 1                             46.595643                               0.0
# 2                             49.832249                               0.0
# 3                             62.837101                               0.0
# 4                             83.993568                               0.0
# ...                                 ...                               ...
# 91230                       2132.869847                               0.0
# 91231                       2151.244069                               0.0
# 91232                       2135.768389                               0.0
# 91233                       2138.146221                               0.0
# 91234                       2150.838296                               0.0
#
#        Location_Center_X  Location_Center_Y  Location_Center_Z  \
# 0            1197.529058          16.961423                  0
# 1            1807.893591          46.781943                  0
# 2             501.791246          49.721100                  0
# 3            1241.517542          62.836596                  0
# 4             968.179583          83.139905                  0
# ...                  ...                ...                ...
# 91230        1982.629846        2133.328200                  0
# 91231         296.091832        2139.881279                  0
# 91232        1451.112813        2136.359877                  0
# 91233         486.206562        2141.333641                  0
# 91234         875.810924        2150.908964                  0
#
#        Location_MaxIntensity_X_D  Location_MaxIntensity_Y_D  \
# 0                         1205.0                        0.0
# 1                         1795.0                       25.0
# 2                          501.0                       57.0
# 3                         1215.0                       55.0
# 4                          993.0                      106.0
# ...                          ...                        ...
# 91230                     1973.0                     2119.0
# 91231                      326.0                     2155.0
# 91232                     1434.0                     2132.0
# 91233                      498.0                     2131.0
# 91234                      870.0                     2148.0
#
#        Location_MaxIntensity_Z_D  Mean_SpotsD_AreaShape_Area  \
# 0                            0.0                         NaN
# 1                            0.0                         NaN
# 2                            0.0                         NaN
# 3                            0.0                         NaN
# 4                            0.0                         NaN
# ...                          ...                         ...
# 91230                        0.0                         NaN
# 91231                        0.0                       246.0
# 91232                        0.0                         NaN
# 91233                        0.0                         NaN
# 91234                        0.0                         NaN
#
#        Mean_SpotsD_Intensity_IntegratedIntensity_D  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 91230                                          NaN
# 91231                                   171.747326
# 91232                                          NaN
# 91233                                          NaN
# 91234                                          NaN
#
#        Mean_SpotsD_Intensity_MeanIntensity_D  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 91230                                    NaN
# 91231                                0.69816
# 91232                                    NaN
# 91233                                    NaN
# 91234                                    NaN
#
#        Mean_SpotsD_Intensity_MedianIntensity_D  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 91230                                      NaN
# 91231                                 0.719371
# 91232                                      NaN
# 91233                                      NaN
# 91234                                      NaN
#
#        Mean_SpotsD_Location_CenterMassIntensity_X_D  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 91230                                           NaN
# 91231                                    325.334227
# 91232                                           NaN
# 91233                                           NaN
# 91234                                           NaN
#
#        Mean_SpotsD_Location_CenterMassIntensity_Y_D  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 91230                                           NaN
# 91231                                   2154.739036
# 91232                                           NaN
# 91233                                           NaN
# 91234                                           NaN
#
#        Mean_SpotsD_Location_CenterMassIntensity_Z_D  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 91230                                           NaN
# 91231                                           0.0
# 91232                                           NaN
# 91233                                           NaN
# 91234                                           NaN
#
#        Mean_SpotsD_Location_Center_X  Mean_SpotsD_Location_Center_Y  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
# ...                              ...                            ...
# 91230                            NaN                            NaN
# 91231                     324.337398                    2154.060976
# 91232                            NaN                            NaN
# 91233                            NaN                            NaN
# 91234                            NaN                            NaN
#
#        Mean_SpotsD_Location_Center_Z  Mean_SpotsD_Location_MaxIntensity_X_D  \
# 0                                NaN                                    NaN
# 1                                NaN                                    NaN
# 2                                NaN                                    NaN
# 3                                NaN                                    NaN
# 4                                NaN                                    NaN
# ...                              ...                                    ...
# 91230                            NaN                                    NaN
# 91231                            0.0                                  324.0
# 91232                            NaN                                    NaN
# 91233                            NaN                                    NaN
# 91234                            NaN                                    NaN
#
#        Mean_SpotsD_Location_MaxIntensity_Y_D  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 91230                                    NaN
# 91231                                 2155.0
# 91232                                    NaN
# 91233                                    NaN
# 91234                                    NaN
#
#        Mean_SpotsD_Location_MaxIntensity_Z_D  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 91230                                    NaN
# 91231                                    0.0
# 91232                                    NaN
# 91233                                    NaN
# 91234                                    NaN
#
#        Mean_SpotsD_Number_Object_Number  Number_Object_Number  Parent_Nuclei
# 0                                   NaN                     1              1
# 1                                   NaN                     2              2
# 2                                   NaN                     3              3
# 3                                   NaN                     4              4
# 4                                   NaN                     5              5
# ...                                 ...                   ...            ...
# 91230                               NaN                   319            319
# 91231                             230.0                   320            320
# 91232                               NaN                   321            321
# 91233                               NaN                   322            322
# 91234                               NaN                   323            323
#
# [91235 rows x 37 columns]
# Experiment name:  ME00028_P4
# Run name:  ME0002
# Plate layout:  /home/ilmoncyte/Documents/analyses/testing_data/layouts/ME00028_P4_layout.csv
# <DataPrepIL.DataPrep object at 0x7fbf59183be0>
# Stain C =  CD36
#        well Names
# 0       NaN     A
# 1    r01c01   NaN
# 2    r01c02   NaN
# 3    r01c03   NaN
# 4    r01c04   NaN
# ..      ...   ...
# 395  r16c20   NaN
# 396  r16c21   NaN
# 397  r16c22   NaN
# 398  r16c23   NaN
# 399  r16c24   NaN
#
# [400 rows x 2 columns]
#        Metadata_Filename  cell_area  DiIOrg    IntDiI   MeanDiI    MedDiI  \
# 0  r03c03f1-ch2_MIP.tiff       1996       0  5.978805  0.002995  0.002960
# 1  r03c03f1-ch2_MIP.tiff       2481       0  7.153643  0.002883  0.002518
#
#    Size_DiIOrg  MeanIntDiI_DiIOrg  MeanMeanDiI_DiIOrg  MeanMedDiI_DiIOrg  \
# 0          NaN                NaN                 NaN                NaN
# 1          NaN                NaN                 NaN                NaN
#
#    experiment  um_cell_area  Monocyte shortnames    well Sample treatment  \
# 0  ME00028_P4     44.607518  negative     r03c03  r03c03  A0001        CM
# 1  ME00028_P4     55.446519  negative     r03c03  r03c03  A0001        CM
#
#   DiIOrg_pos  um_DiIOrg_size  total_DiIOrg_size  um_total_DiIOrg_size  \
# 0   negative             NaN                NaN                   NaN
# 1   negative             NaN                NaN                   NaN
#
#    total_DiI_meanint_of_DiIOrg  total_DiI_meanmean_of_DiIOrg  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
#
#    total_DiI_meanmed_of_DiIOrg
# 0                          NaN
# 1                          NaN
#        Metadata_Filename  cell_area  DiIOrg    IntDiI   MeanDiI    MedDiI  \
# 0  r03c03f1-ch2_MIP.tiff     1996.0     0.0  5.978805  0.002995  0.002960
# 1  r03c03f1-ch2_MIP.tiff     2481.0     0.0  7.153643  0.002883  0.002518
#
#    Size_DiIOrg  MeanIntDiI_DiIOrg  MeanMeanDiI_DiIOrg  MeanMedDiI_DiIOrg  \
# 0          NaN                NaN                 NaN                NaN
# 1          NaN                NaN                 NaN                NaN
#
#    experiment  um_cell_area  Monocyte shortnames    well Sample treatment  \
# 0  ME00028_P4     44.607518  negative     r03c03  r03c03  A0001        CM
# 1  ME00028_P4     55.446519  negative     r03c03  r03c03  A0001        CM
#
#   DiIOrg_pos  um_DiIOrg_size  total_DiIOrg_size  um_total_DiIOrg_size  \
# 0   negative             NaN                NaN                   NaN
# 1   negative             NaN                NaN                   NaN
#
#    total_DiI_meanint_of_DiIOrg  total_DiI_meanmean_of_DiIOrg  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
#
#    total_DiI_meanmed_of_DiIOrg
# 0                          NaN
# 1                          NaN
# removed  5  cells out of  91235  based on cell area
