# %%
#import necessary python packages
import pandas as pd
import numpy as np
import sys
import seaborn as sns
sns.set_context('paper')

#provide the path to local folder containing python functions for pbmc analysis
sys.path.insert(1, '/home/ilmoncyte/Documents/analyses/cell_data_analyses/pbmc_analysis_tools/')

#import functions for pbmc analysis
from DataPrepIL import DataPrep
from NormaliseData import NormaliseData
from Plate import Plate
from DataCleanup import DataCleanup
from WellCalc import WellCalc
from DrawHeatmap import DrawHeatmap
from FoldCalc import FoldCalc

#provide paths to used folders
where = '/home/ilmoncyte/Documents/analyses/testing_data/'
layouts_folder = where+ 'layouts/' # where your csv layout file is located
results_folder = where+ 'cellp_results/' #where is your cellprofiler output folder located
output_folder = where+ 'out_results/'

# %%
pd.set_option('display.max_columns', None)
#provide the name of the cellprofiler output file
filename = 'ME00028_P7_Cells.csv' 


file_loc = results_folder + filename
print('Data location: ',file_loc)

#read the cellprofiler output file and extract experiment and run name from the filename
sr_all = pd.read_csv(file_loc)
print(sr_all)
exp_name = filename[:-10]
print('Experiment name: ',exp_name)
run_name = filename[0:6]
print('Run name: ', run_name)


experimentlayout = layouts_folder+exp_name+'_layout.csv'
print('Plate layout: ',experimentlayout)


#initialise the class for transforming the dataframe to readable format
my_frame = DataPrep(file_loc, exp_name)
print(my_frame)
#set the stain name for channel C

#set the stain name for channel D
my_frame.set_stain_d('DiI')
#print('Stain C = ', my_frame.stain_c)

#set the cut_off
my_frame.set_cutoff(100)

dat = my_frame.org_calc(experimentlayout, 384)
print(dat.head(2))
#remove outliers on a single-cell level
clean_data = DataCleanup(5)

cdat = clean_data.cl_fraction(dat,'cell_area')
print(cdat.head(2))
print('removed ', dat.shape[0] - cdat.shape[0], ' cells out of ', dat.shape[0], ' based on cell area')

#cdat1 = clean_data.cl_well_fract(cdat, 'Size_DiIOrg')
#print('removed ', cdat.shape[0] - cdat1.shape[0], ' cells out of ', cdat.shape[0], ' based on DiIOrg size')


#save single-cell data with outliers removed 
cdat.to_csv(output_folder+'single_cell_cleaned/'+exp_name+'_cell_clean.csv')
# Out:
# Data location:  /home/ilmoncyte/Documents/analyses/testing_data/cellp_results/ME00028_P7_Cells.csv
#        ImageNumber  ObjectNumber  Metadata_FileLocation  \
# 0                1             1                    NaN
# 1                1             2                    NaN
# 2                1             3                    NaN
# 3                1             4                    NaN
# 4                1             5                    NaN
# ...            ...           ...                    ...
# 81456          396           315                    NaN
# 81457          396           316                    NaN
# 81458          396           317                    NaN
# 81459          396           318                    NaN
# 81460          396           319                    NaN
#
#            Metadata_Filename    Metadata_Filename.1  Metadata_Frame  \
# 0      r03c03f1-ch2_MIP.tiff  r03c03f1-ch2_MIP.tiff               0
# 1      r03c03f1-ch2_MIP.tiff  r03c03f1-ch2_MIP.tiff               0
# 2      r03c03f1-ch2_MIP.tiff  r03c03f1-ch2_MIP.tiff               0
# 3      r03c03f1-ch2_MIP.tiff  r03c03f1-ch2_MIP.tiff               0
# 4      r03c03f1-ch2_MIP.tiff  r03c03f1-ch2_MIP.tiff               0
# ...                      ...                    ...             ...
# 81456  r14c04f9-ch2_MIP.tiff  r14c04f9-ch2_MIP.tiff               0
# 81457  r14c04f9-ch2_MIP.tiff  r14c04f9-ch2_MIP.tiff               0
# 81458  r14c04f9-ch2_MIP.tiff  r14c04f9-ch2_MIP.tiff               0
# 81459  r14c04f9-ch2_MIP.tiff  r14c04f9-ch2_MIP.tiff               0
# 81460  r14c04f9-ch2_MIP.tiff  r14c04f9-ch2_MIP.tiff               0
#
#        Metadata_Series  AreaShape_Area  Children_SpotsD_Count  \
# 0                    0            1053                      0
# 1                    0            1356                      0
# 2                    0            3389                      0
# 3                    0            2719                      0
# 4                    0            4463                      0
# ...                ...             ...                    ...
# 81456                0            1810                      0
# 81457                0            4218                      0
# 81458                0            2870                      0
# 81459                0            3400                      0
# 81460                0            1633                      0
#
#        Intensity_IntegratedIntensity_D  Intensity_MeanIntensity_D  \
# 0                             5.323644                   0.005056
# 1                             3.435065                   0.002533
# 2                            44.015336                   0.012988
# 3                            15.369650                   0.005653
# 4                            14.309148                   0.003206
# ...                                ...                        ...
# 81456                         4.154803                   0.002295
# 81457                        16.772686                   0.003976
# 81458                         7.562844                   0.002635
# 81459                        16.221912                   0.004771
# 81460                         3.668711                   0.002247
#
#        Intensity_MedianIntensity_D  Location_CenterMassIntensity_X_D  \
# 0                         0.002441                        470.800573
# 1                         0.002045                        884.402151
# 2                         0.008011                        732.492730
# 3                         0.002609                        885.447132
# 4                         0.001968                       1954.396397
# ...                            ...                               ...
# 81456                     0.002152                       1108.277055
# 81457                     0.001877                       1846.184920
# 81458                     0.002045                        847.481019
# 81459                     0.004089                        264.726761
# 81460                     0.001923                         24.531695
#
#        Location_CenterMassIntensity_Y_D  Location_CenterMassIntensity_Z_D  \
# 0                             16.204726                               0.0
# 1                             12.587614                               0.0
# 2                             23.637023                               0.0
# 3                             48.102563                               0.0
# 4                             60.279787                               0.0
# ...                                 ...                               ...
# 81456                       2078.686534                               0.0
# 81457                       2102.501282                               0.0
# 81458                       2125.765210                               0.0
# 81459                       2125.077053                               0.0
# 81460                       2145.248518                               0.0
#
#        Location_Center_X  Location_Center_Y  Location_Center_Z  \
# 0             473.147198          10.926876                  0
# 1             887.637168          11.135693                  0
# 2             734.042195          26.765713                  0
# 3             898.621552          44.006988                  0
# 4            1951.714094          51.389648                  0
# ...                  ...                ...                ...
# 81456        1107.544751        2078.932044                  0
# 81457        1831.298246        2112.740398                  0
# 81458         848.229617        2131.018467                  0
# 81459         264.000294        2127.508235                  0
# 81460          24.039192        2143.315370                  0
#
#        Location_MaxIntensity_X_D  Location_MaxIntensity_Y_D  \
# 0                          465.0                       24.0
# 1                          867.0                       22.0
# 2                          727.0                       20.0
# 3                          866.0                       48.0
# 4                         1955.0                       86.0
# ...                          ...                        ...
# 81456                     1103.0                     2078.0
# 81457                     1859.0                     2091.0
# 81458                      838.0                     2108.0
# 81459                      276.0                     2118.0
# 81460                       41.0                     2159.0
#
#        Location_MaxIntensity_Z_D  Mean_SpotsD_AreaShape_Area  \
# 0                            0.0                         NaN
# 1                            0.0                         NaN
# 2                            0.0                         NaN
# 3                            0.0                         NaN
# 4                            0.0                         NaN
# ...                          ...                         ...
# 81456                        0.0                         NaN
# 81457                        0.0                         NaN
# 81458                        0.0                         NaN
# 81459                        0.0                         NaN
# 81460                        0.0                         NaN
#
#        Mean_SpotsD_Intensity_IntegratedIntensity_D  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 81456                                          NaN
# 81457                                          NaN
# 81458                                          NaN
# 81459                                          NaN
# 81460                                          NaN
#
#        Mean_SpotsD_Intensity_MeanIntensity_D  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 81456                                    NaN
# 81457                                    NaN
# 81458                                    NaN
# 81459                                    NaN
# 81460                                    NaN
#
#        Mean_SpotsD_Intensity_MedianIntensity_D  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 81456                                      NaN
# 81457                                      NaN
# 81458                                      NaN
# 81459                                      NaN
# 81460                                      NaN
#
#        Mean_SpotsD_Location_CenterMassIntensity_X_D  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 81456                                           NaN
# 81457                                           NaN
# 81458                                           NaN
# 81459                                           NaN
# 81460                                           NaN
#
#        Mean_SpotsD_Location_CenterMassIntensity_Y_D  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 81456                                           NaN
# 81457                                           NaN
# 81458                                           NaN
# 81459                                           NaN
# 81460                                           NaN
#
#        Mean_SpotsD_Location_CenterMassIntensity_Z_D  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 81456                                           NaN
# 81457                                           NaN
# 81458                                           NaN
# 81459                                           NaN
# 81460                                           NaN
#
#        Mean_SpotsD_Location_Center_X  Mean_SpotsD_Location_Center_Y  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
# ...                              ...                            ...
# 81456                            NaN                            NaN
# 81457                            NaN                            NaN
# 81458                            NaN                            NaN
# 81459                            NaN                            NaN
# 81460                            NaN                            NaN
#
#        Mean_SpotsD_Location_Center_Z  Mean_SpotsD_Location_MaxIntensity_X_D  \
# 0                                NaN                                    NaN
# 1                                NaN                                    NaN
# 2                                NaN                                    NaN
# 3                                NaN                                    NaN
# 4                                NaN                                    NaN
# ...                              ...                                    ...
# 81456                            NaN                                    NaN
# 81457                            NaN                                    NaN
# 81458                            NaN                                    NaN
# 81459                            NaN                                    NaN
# 81460                            NaN                                    NaN
#
#        Mean_SpotsD_Location_MaxIntensity_Y_D  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 81456                                    NaN
# 81457                                    NaN
# 81458                                    NaN
# 81459                                    NaN
# 81460                                    NaN
#
#        Mean_SpotsD_Location_MaxIntensity_Z_D  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 81456                                    NaN
# 81457                                    NaN
# 81458                                    NaN
# 81459                                    NaN
# 81460                                    NaN
#
#        Mean_SpotsD_Number_Object_Number  Number_Object_Number  Parent_Nuclei
# 0                                   NaN                     1              1
# 1                                   NaN                     2              2
# 2                                   NaN                     3              3
# 3                                   NaN                     4              4
# 4                                   NaN                     5              5
# ...                                 ...                   ...            ...
# 81456                               NaN                   315            315
# 81457                               NaN                   316            316
# 81458                               NaN                   317            317
# 81459                               NaN                   318            318
# 81460                               NaN                   319            319
#
# [81461 rows x 37 columns]
# Experiment name:  ME00028_P7
# Run name:  ME0002
# Plate layout:  /home/ilmoncyte/Documents/analyses/testing_data/layouts/ME00028_P7_layout.csv
# <DataPrepIL.DataPrep object at 0x70abd59556f0>
#        well Names
# 0       NaN     A
# 1    r01c01   NaN
# 2    r01c02   NaN
# 3    r01c03   NaN
# 4    r01c04   NaN
# ..      ...   ...
# 395  r16c20   NaN
# 396  r16c21   NaN
# 397  r16c22   NaN
# 398  r16c23   NaN
# 399  r16c24   NaN
#
# [400 rows x 2 columns]
#        Metadata_Filename  cell_area  DiIOrg    IntDiI   MeanDiI    MedDiI  \
# 0  r03c03f1-ch2_MIP.tiff     1053.0     0.0  5.323644  0.005056  0.002441
# 1  r03c03f1-ch2_MIP.tiff     1356.0     0.0  3.435065  0.002533  0.002045
#
#    Size_DiIOrg  MeanIntDiI_DiIOrg  MeanMeanDiI_DiIOrg  MeanMedDiI_DiIOrg  \
# 0          NaN                NaN                 NaN                NaN
# 1          NaN                NaN                 NaN                NaN
#
#    experiment  um_cell_area  Monocyte shortnames    well Sample treatment  \
# 0  ME00028_P7     23.532924  negative     r03c03  r03c03  A0001     NAIVE
# 1  ME00028_P7     30.304506  negative     r03c03  r03c03  A0001     NAIVE
#
#   DiIOrg_pos  um_DiIOrg_size  total_DiIOrg_size  um_total_DiIOrg_size  \
# 0   negative             NaN                NaN                   NaN
# 1   negative             NaN                NaN                   NaN
#
#    total_DiI_meanint_of_DiIOrg  total_DiI_meanmean_of_DiIOrg  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
#
#    total_DiI_meanmed_of_DiIOrg
# 0                          NaN
# 1                          NaN
#        Metadata_Filename  cell_area  DiIOrg    IntDiI   MeanDiI    MedDiI  \
# 0  r03c03f1-ch2_MIP.tiff     1053.0     0.0  5.323644  0.005056  0.002441
# 1  r03c03f1-ch2_MIP.tiff     1356.0     0.0  3.435065  0.002533  0.002045
#
#    Size_DiIOrg  MeanIntDiI_DiIOrg  MeanMeanDiI_DiIOrg  MeanMedDiI_DiIOrg  \
# 0          NaN                NaN                 NaN                NaN
# 1          NaN                NaN                 NaN                NaN
#
#    experiment  um_cell_area  Monocyte shortnames    well Sample treatment  \
# 0  ME00028_P7     23.532924  negative     r03c03  r03c03  A0001     NAIVE
# 1  ME00028_P7     30.304506  negative     r03c03  r03c03  A0001     NAIVE
#
#   DiIOrg_pos  um_DiIOrg_size  total_DiIOrg_size  um_total_DiIOrg_size  \
# 0   negative             NaN                NaN                   NaN
# 1   negative             NaN                NaN                   NaN
#
#    total_DiI_meanint_of_DiIOrg  total_DiI_meanmean_of_DiIOrg  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
#
#    total_DiI_meanmed_of_DiIOrg
# 0                          NaN
# 1                          NaN
# removed  13  cells out of  81462  based on cell area
